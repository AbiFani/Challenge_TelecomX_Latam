# %% [markdown]
# <a href="https://colab.research.google.com/github/AbiFani/Challenge_TelecomX_Latam/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
# importar biblioteca pandas
import pandas as pd

# %%
# leer archivo json
datos = pd.read_json('https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json')

# %%
#mostrar los primeros 5 filas
datos.head(10)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# ...

# %% [markdown]
# #🔧 Transformación

# %%
# muestra el tipo de dato del dataframe clientes
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
# muestra el tipo de datos
datos.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
# muestra el tamaño del dataframe
datos.shape
# Out:
# (7267, 6)

# %%
# describe las columnas del dataframe
datos.describe()
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %%
datos.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
# guardar en un dataframe la columna customerID
clientes_customerID = datos['customerID']
clientes_customerID
# Out:
# 0       0002-ORFBO
# 1       0003-MKNFE
# 2       0004-TLHLJ
# 3       0011-IGKFF
# 4       0013-EXCHZ
#            ...
# 7262    9987-LUTYD
# 7263    9992-RRAMN
# 7264    9992-UJOEL
# 7265    9993-LHIEB
# 7266    9995-HOTOH
# Name: customerID, Length: 7267, dtype: object

# %%
# guardar en un dataframe la columna Churn
clientes_Churn = datos['Churn']
clientes_Churn
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %%
# Normalizando archivo Json columna customer
clientes_normalizados = pd.json_normalize(datos['customer'])
clientes_normalizados
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
# Nomalizando columna phone
cliente_telefono = pd.json_normalize(datos['phone'])
cliente_telefono
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
# Nomalizando columna internet
cliente_internet = pd.json_normalize(datos['internet'])
cliente_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
# Nomalizando columna account
cliente_account = pd.json_normalize(datos['account'])
cliente_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
# guadar todo en un nuevo dataframe llamado datos_nomalizados, las columnas normalizadas

datos_normalizados = pd.concat([clientes_customerID,clientes_Churn, clientes_normalizados, cliente_telefono, cliente_internet, cliente_account], axis=1)

# %%
# mostrar dataframe
datos_normalizados
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
# mostrar filas y columnas
datos_normalizados.shape
# Out:
# (7267, 21)

# %%
#mostrar primeras 5 filas del datframe
datos_normalizados.head(5)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
# conocer el tipo de datos del dataframe
datos_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# para trabajar con datos numericos en pyton usar biblioteca Numpy
import numpy as np

# %%
# dataframe con el nombre de las columnas
columnas = list(datos_normalizados.columns)
columnas
# Out:
# ['customerID',
#  'Churn',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Charges.Monthly',
#  'Charges.Total']

# %%
# explorar con el metodo explode, para tener datos individualmente
datos_normalizados = datos_normalizados.explode(columnas)
# datos_normalizados

# %%
# mostrar primeras filas
datos_normalizados.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
# reemplazar datos en las columnas del dataframe
datos_normalizados = datos_normalizados.replace(' ', np.nan)
datos_normalizados
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
# conocer el tipo de dato
datos_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# Transformar columna Charges.Total a tipo de dato decimal , con float64
datos_normalizados['Charges.Total'] = datos_normalizados['Charges.Total'].astype(np.float64)

# %%
# mostrar el cambio en la columna
datos_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# mostrar el cambio tipo de datos
datos_normalizados.dtypes
# Out:
# customerID           object
# Churn                object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total       float64
# dtype: object

# %%
# agregar columna Cuentas_Diarias Utiliza la facturación mensual para calcular el valor diario,
# proporcionando una visión más detallada del comportamiento de los clientes a lo largo del tiempo.
datos_normalizados['Cuentas_Diarias'] = datos_normalizados['Charges.Monthly'] / 30
datos_normalizados
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# ...

# %%
# mostar el tipo de datos del dataframe
datos_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# EXTRA
#  convertir valores textuales como "YES" y "No" en valores binarios (1 y 0) y guardarlo en el dataframe
# datos_normalizados['Churn'] = datos_normalizados['Churn'].map({'Yes': 1, 'No': 0})

# %%
# Reemplazar valor de la columna MultipleLines, No phone service, por No
# datos_normalizados['MultipleLines'] = datos_normalizados['MultipleLines'].replace('No phone service', 'No')
datos_normalizados['MultipleLines'].replace('No phone service', 'No')
# Out:
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4        No
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: MultipleLines, Length: 7267, dtype: object

# %%
# guardalo en la columna del dataframe
datos_normalizados['MultipleLines'] = datos_normalizados['MultipleLines'].replace('No phone service', 'No')

# %%
# mostrar el datframe con los cambios
datos_normalizados
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService MultipleLines InternetService  ... DeviceProtection  \
# ...

# %%
# transformar y reemplazar valores de multiples columnas
datos_normalizados[['Churn', 'OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']]
# Out:
#      Churn OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0       No             No          Yes               No         Yes
# 1       No             No           No               No          No
# 2      Yes             No           No              Yes          No
# 3      Yes             No          Yes              Yes          No
# 4      Yes             No           No               No         Yes
# ...    ...            ...          ...              ...         ...
# 7262    No            Yes           No               No         Yes
# 7263   Yes             No           No               No          No
# 7264    No             No          Yes               No          No
# 7265    No            Yes           No              Yes         Yes
# 7266    No            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 0            Yes              No
# 1             No             Yes
# 2             No              No
# ...

# %%
# guardarlo en el dataframe
datos_normalizados[['Churn','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']] = datos_normalizados[['Churn','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']].replace({'No internet service':'No','':'No'})

# %%
# mostrarlo en el dataframe
datos_normalizados
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService MultipleLines InternetService  ... DeviceProtection  \
# ...

# %%
# tranformando multiples columnas
datos_normalizados[['Churn','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']]
# Out:
#      Churn Partner Dependents PhoneService MultipleLines OnlineSecurity  \
# 0       No     Yes        Yes          Yes            No             No
# 1       No      No         No          Yes           Yes             No
# 2      Yes      No         No          Yes            No             No
# 3      Yes     Yes         No          Yes            No             No
# 4      Yes     Yes         No          Yes            No             No
# ...    ...     ...        ...          ...           ...            ...
# 7262    No      No         No          Yes            No            Yes
# 7263   Yes     Yes         No          Yes           Yes             No
# 7264    No      No         No          Yes            No             No
# 7265    No     Yes        Yes          Yes            No            Yes
# 7266    No     Yes        Yes           No            No            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# ...

# %%
# reemplazar multiples columnas con valores textuales como "Sí" y "No" en valores binarios (1 y 0)
datos_normalizados[['Churn','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']].replace({'Yes': 1, 'No': 0})
# Out:
# /tmp/ipython-input-3325947789.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datos_normalizados[['Churn','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']].replace({'Yes': 1, 'No': 0})
#       Churn  Partner  Dependents  PhoneService  MultipleLines  OnlineSecurity  \
# 0         0        1           1             1              0               0
# 1         0        0           0             1              1               0
# 2         1        0           0             1              0               0
# 3         1        1           0             1              0               0
# ...

# %%
# guardarlo en el dataframe
datos_normalizados[['Churn','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']] = datos_normalizados[['Churn','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']] = datos_normalizados[['Churn','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']] = datos_normalizados[['Churn','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling']].replace({'Yes': 1, 'No': 0})
datos_normalizados
# Out:
# /tmp/ipython-input-3906093973.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
# mostar tipo de dato
datos_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   int64
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   int64
#  5   Dependents        7267 non-null   int64
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   int64
#  8   MultipleLines     7267 non-null   int64
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   int64
#  11  OnlineBackup      7267 non-null   int64
#  12  DeviceProtection  7267 non-null   int64
#  13  TechSupport       7267 non-null   int64
#  14  StreamingTV       7267 non-null   int64
#  15  StreamingMovies   7267 non-null   int64
# ...

# %%
# EXTRA
# renombrar y traducir el nombre de las columnas del dataframe
datos_normalizados.rename(columns={'customerID': 'ID_Cliente', 'Churn': 'Estado', 'gender': 'Genero', 'SeniorCitizen': 'Jubilado', 'Partner': 'Pareja', 'Dependents': 'Dependientes', 'tenure': 'Plazo', 'PhoneService': 'Servicio_Telefonico', 'MultipleLines': 'Multiples_Lineas', 'InternetService': 'Servicio_Internet', 'OnlineSecurity': 'Seguridad_Online', 'OnlineBackup': 'Copia_Seguridad_Online', 'DeviceProtection': 'Proteccion_Dispositivos', 'TechSupport': 'Soporte_Tecnico', 'StreamingTV': 'Suscripcion_TV', 'StreamingMovies': 'Suscripcion_Peliculas', 'Contract': 'Contrato', 'PaperlessBilling': 'Facturacion_Electronica', 'PaymentMethod': 'Metodo_Pago', 'Charges.Monthly': 'Facturacion_Mensual', 'Charges.Total': 'Facturacion_Total'})
# Out:
#       ID_Cliente  Estado  Genero  Jubilado  Pareja  Dependientes  Plazo  \
# 0     0002-ORFBO       0  Female         0       1             1      9
# 1     0003-MKNFE       0    Male         0       0             0      9
# 2     0004-TLHLJ       1    Male         0       0             0      4
# 3     0011-IGKFF       1    Male         1       1             0     13
# 4     0013-EXCHZ       1  Female         1       1             0      3
# ...          ...     ...     ...       ...     ...           ...    ...
# 7262  9987-LUTYD       0  Female         0       0             0     13
# 7263  9992-RRAMN       1    Male         0       1             0     22
# 7264  9992-UJOEL       0    Male         0       0             0      2
# 7265  9993-LHIEB       0    Male         0       1             1     67
# 7266  9995-HOTOH       0    Male         0       1             1     63
#
#       Servicio_Telefonico  Multiples_Lineas Servicio_Internet  ...  \
# ...

# %%
# guardar cambios en el dataframe
nuevo_dataframe = datos_normalizados.rename(columns={'customerID': 'ID_Cliente', 'Churn': 'Estado', 'gender': 'Genero', 'SeniorCitizen': 'Jubilado', 'Partner': 'Pareja', 'Dependents': 'Dependientes', 'tenure': 'Plazo', 'PhoneService': 'Servicio_Telefonico', 'MultipleLines': 'Multiples_Lineas', 'InternetService': 'Servicio_Internet', 'OnlineSecurity': 'Seguridad_Online', 'OnlineBackup': 'Copia_Seguridad_Online', 'DeviceProtection': 'Proteccion_Dispositivos', 'TechSupport': 'Soporte_Tecnico', 'StreamingTV': 'Suscripcion_TV', 'StreamingMovies': 'Suscripcion_Peliculas', 'Contract': 'Contrato', 'PaperlessBilling': 'Facturacion_Electronica', 'PaymentMethod': 'Metodo_Pago', 'Charges.Monthly': 'Facturacion_Mensual', 'Charges.Total': 'Facturacion_Total'})

# %%
# mostrarlo en el datframe
nuevo_dataframe
# Out:
#       ID_Cliente  Estado  Genero  Jubilado  Pareja  Dependientes  Plazo  \
# 0     0002-ORFBO       0  Female         0       1             1      9
# 1     0003-MKNFE       0    Male         0       0             0      9
# 2     0004-TLHLJ       1    Male         0       0             0      4
# 3     0011-IGKFF       1    Male         1       1             0     13
# 4     0013-EXCHZ       1  Female         1       1             0      3
# ...          ...     ...     ...       ...     ...           ...    ...
# 7262  9987-LUTYD       0  Female         0       0             0     13
# 7263  9992-RRAMN       1    Male         0       1             0     22
# 7264  9992-UJOEL       0    Male         0       0             0      2
# 7265  9993-LHIEB       0    Male         0       1             1     67
# 7266  9995-HOTOH       0    Male         0       1             1     63
#
#       Servicio_Telefonico  Multiples_Lineas Servicio_Internet  ...  \
# ...

# %%
# mostar primeras 10 filas
nuevo_dataframe.head(10)
# Out:
#    ID_Cliente  Estado  Genero  Jubilado  Pareja  Dependientes  Plazo  \
# 0  0002-ORFBO       0  Female         0       1             1      9
# 1  0003-MKNFE       0    Male         0       0             0      9
# 2  0004-TLHLJ       1    Male         0       0             0      4
# 3  0011-IGKFF       1    Male         1       1             0     13
# 4  0013-EXCHZ       1  Female         1       1             0      3
# 5  0013-MHZWF       0  Female         0       0             1      9
# 6  0013-SMEOE       0  Female         1       1             0     71
# 7  0014-BMAQU       0    Male         0       1             0     63
# 8  0015-UOCOJ       0  Female         1       0             0      7
# 9  0016-QLJIS       0  Female         0       1             1     65
#
#    Servicio_Telefonico  Multiples_Lineas Servicio_Internet  ...  \
# 0                    1                 0               DSL  ...
# 1                    1                 1               DSL  ...
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
#realiza un análisis descriptivo de los datos
nuevo_dataframe.describe()
# Out:
#             Estado     Jubilado       Pareja  Dependientes        Plazo  \
# count  7267.000000  7267.000000  7267.000000   7267.000000  7267.000000
# mean      0.257190     0.162653     0.484106      0.300124    32.346498
# std       0.437115     0.369074     0.499782      0.458343    24.571773
# min       0.000000     0.000000     0.000000      0.000000     0.000000
# 25%       0.000000     0.000000     0.000000      0.000000     9.000000
# 50%       0.000000     0.000000     0.000000      0.000000    29.000000
# 75%       1.000000     0.000000     1.000000      1.000000    55.000000
# max       1.000000     1.000000     1.000000      1.000000    72.000000
#
#        Servicio_Telefonico  Multiples_Lineas  Seguridad_Online  \
# count          7267.000000       7267.000000       7267.000000
# mean              0.902711          0.421770          0.285950
# std               0.296371          0.493876          0.451897
# min               0.000000          0.000000          0.000000
# ...

# %%
# crea un dataframe y calcula la media de los clientes, asigna 'media' como la etiqueta del índice
media = nuevo_dataframe.select_dtypes(include=np.number).mean()
media.name = 'media'

# %%
media
# Out:
# Estado                        0.257190
# Jubilado                      0.162653
# Pareja                        0.484106
# Dependientes                  0.300124
# Plazo                        32.346498
# Servicio_Telefonico           0.902711
# Multiples_Lineas              0.421770
# Seguridad_Online              0.285950
# Copia_Seguridad_Online        0.344571
# Proteccion_Dispositivos       0.342782
# Soporte_Tecnico               0.289528
# Suscripcion_TV                0.383927
# Suscripcion_Peliculas         0.387505
# Facturacion_Electronica       0.593230
# Facturacion_Mensual          64.720098
# Facturacion_Total          2280.634213
# Cuentas_Diarias               2.157337
# Name: media, dtype: float64

# %%
# crea un dataframe y calcula la mediana de los clientes, asigna 'mediana' como la etiqueta del índice
mediana = nuevo_dataframe.select_dtypes(include=np.number).median()
mediana.name = 'mediana'

# %%
mediana
# Out:
# Estado                        0.000000
# Jubilado                      0.000000
# Pareja                        0.000000
# Dependientes                  0.000000
# Plazo                        29.000000
# Servicio_Telefonico           1.000000
# Multiples_Lineas              0.000000
# Seguridad_Online              0.000000
# Copia_Seguridad_Online        0.000000
# Proteccion_Dispositivos       0.000000
# Soporte_Tecnico               0.000000
# Suscripcion_TV                0.000000
# Suscripcion_Peliculas         0.000000
# Facturacion_Electronica       1.000000
# Facturacion_Mensual          70.300000
# Facturacion_Total          1391.000000
# Cuentas_Diarias               2.343333
# Name: mediana, dtype: float64

# %%
# crea un dataframe y calcula la desviacion estandar de los clientes, asigna 'desviacion estandar' como la etiqueta del índice
desviacion_estandar = nuevo_dataframe.select_dtypes(include=np.number).std()
desviacion_estandar.name = 'desviacion estandar'

# %%
desviacion_estandar
# Out:
# Estado                        0.437115
# Jubilado                      0.369074
# Pareja                        0.499782
# Dependientes                  0.458343
# Plazo                        24.571773
# Servicio_Telefonico           0.296371
# Multiples_Lineas              0.493876
# Seguridad_Online              0.451897
# Copia_Seguridad_Online        0.475261
# Proteccion_Dispositivos       0.474672
# Soporte_Tecnico               0.453575
# Suscripcion_TV                0.486374
# Suscripcion_Peliculas         0.487214
# Facturacion_Electronica       0.491265
# Facturacion_Mensual          30.129572
# Facturacion_Total          2268.632997
# Cuentas_Diarias               1.004319
# Name: desviacion estandar, dtype: float64

# %%
# crea un dataframe y calcula la desviacion estandar de los clientes, asigna 'desviacion estandar' como la etiqueta del índice
estilo = pd.DataFrame(desviacion_estandar).style
estilo.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_3a0e4_row0_col0, #T_3a0e4_row1_col0, #T_3a0e4_row2_col0, #T_3a0e4_row3_col0, #T_3a0e4_row5_col0, #T_3a0e4_row6_col0, #T_3a0e4_row7_col0, #T_3a0e4_row8_col0, #T_3a0e4_row9_col0, #T_3a0e4_row10_col0, #T_3a0e4_row11_col0, #T_3a0e4_row12_col0, #T_3a0e4_row13_col0, #T_3a0e4_row16_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_3a0e4_row4_col0 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_3a0e4_row14_col0 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_3a0e4_row15_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3a0e4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a0e4_level0_col0" class="col_heading level0 col0" >desviacion estandar</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a0e4_level0_row0" class="row_heading level0 row0" >Estado</th>
# ...

# %% [markdown]
# ## Evasion por permanencia del cliente

# %%
# Importar bibliotecas
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# muestra los clientes que permanecieron y los que se dieron de baja
nuevo_dataframe['Estado'].value_counts()
# Out:
# Estado
# 0    5398
# 1    1869
# Name: count, dtype: int64

# %%
# guardalo en un datframe conteo_clientes
conteo_clientes = nuevo_dataframe['Estado'].value_counts()
conteo_clientes
# Out:
# Estado
# 0    5398
# 1    1869
# Name: count, dtype: int64

# %%
# modificar columna count
conteo_clientes.name = 'N°. de clientes'
conteo_clientes
# Out:
# Estado
# 0    5398
# 1    1869
# Name: N°. de clientes, dtype: int64

# %%
# ordenalos de menor a mayor
conteo_clientes = conteo_clientes.sort_values()
conteo_clientes
# Out:
# Estado
# 1    1869
# 0    5398
# Name: N°. de clientes, dtype: int64

# %%
# grafico de barras con los clientes que permanecieron y los que se dieron de baja
plt.figure(figsize=(3,4))
# Usamos conteo_clientes.index para el eje X (los valores 0 y 1) y conteo_clientes.values para el eje Y (sus conteos)
plt.bar(conteo_clientes.index.astype(str), conteo_clientes.values, color=['blue', 'red'])
plt.title('Evasión de clientes: Permanecieron vs. Se dieron de baja')
plt.xlabel('Estado del Cliente (0: No se dio de baja, 1: Se dio de baja)')
plt.ylabel('Número de clientes')
# Personalizamos las etiquetas del eje X para mayor claridad
plt.xticks([0, 1], ['Permanecieron', 'Se dieron de baja'])
plt.show()

# %% [markdown]
# ## Evasion por genero de los clientes

# %%
# crea un dataframe y crea un conteo de genero de los clientes
conteo_genero = nuevo_dataframe['Genero'].value_counts()
conteo_genero
# Out:
# Genero
# Male      3675
# Female    3592
# Name: count, dtype: int64

# %%
# modifica en nombre de la columna count por 'N°. de clientes'
conteo_genero.name = 'N°. de clientes'
conteo_genero
# Out:
# Genero
# Male      3675
# Female    3592
# Name: N°. de clientes, dtype: int64

# %%
# modificar el nombre de las filas en español
conteo_genero.index = ['Masculino', 'Femenino']
conteo_genero
# Out:
# Masculino    3675
# Femenino     3592
# Name: N°. de clientes, dtype: int64

# %%
# colocar nombre del indice 'Genero'
conteo_genero.index.name = 'Genero'
conteo_genero
# Out:
# Genero
# Masculino    3675
# Femenino     3592
# Name: N°. de clientes, dtype: int64

# %%
# grafico de clientes por genero
plt.figure(figsize=(3,4))
plt.bar(conteo_genero.index, conteo_genero.values, color=['skyblue', 'pink'])
plt.title('Evasión de clientes: Género')
plt.xlabel('Genero')
plt.ylabel('Número de clientes')
plt.show()

# %% [markdown]
# ## Evasion por tipo de contrato de los clientes

# %%
# crea un dataframe y realiza un conteo del tipo de contrato de los clientes
conteo_contrato = nuevo_dataframe['Contrato'].value_counts()
conteo_contrato
# Out:
# Contrato
# Month-to-month    4005
# Two year          1743
# One year          1519
# Name: count, dtype: int64

# %%
# modifica en nombre de la columna count por 'N°. de clientes'
conteo_contrato.name = 'N°. de clientes'
conteo_contrato
# Out:
# Contrato
# Month-to-month    4005
# Two year          1743
# One year          1519
# Name: N°. de clientes, dtype: int64

# %%
# modificar el nombre de las filas en español
conteo_contrato.index = ['Mensual', 'Trimestral', 'Anual']
conteo_contrato
# Out:
# Mensual       4005
# Trimestral    1743
# Anual         1519
# Name: N°. de clientes, dtype: int64

# %%
# nombre del indice 'Tipo de contrato'
conteo_contrato.index.name = 'Tipo de contrato'
conteo_contrato
# Out:
# Tipo de contrato
# Mensual       4005
# Trimestral    1743
# Anual         1519
# Name: N°. de clientes, dtype: int64

# %%
# ordenalos de menor a mayor
conteo_contrato = conteo_contrato.sort_values()
conteo_contrato
# Out:
# Tipo de contrato
# Anual         1519
# Trimestral    1743
# Mensual       4005
# Name: N°. de clientes, dtype: int64

# %%
# realiza un grafico de lineas de menor al mayor
plt.figure(figsize=(3,4))
plt.plot(conteo_contrato.index, conteo_contrato.values, marker='o', linestyle='-', color='blue')
plt.title('Evasión de clientes: Tipo de contrato')
plt.xlabel('Tipo de contrato')
plt.ylabel('Número de clientes')
plt.show()

# %% [markdown]
# ## Evasion por metodo de pago de los clientes

# %%
# crea un datframe y realiza un conteo de los metodos de pago de los clientes
conteo_metodo_pago = nuevo_dataframe['Metodo_Pago'].value_counts()
conteo_metodo_pago
# Out:
# Metodo_Pago
# Electronic check             2445
# Mailed check                 1665
# Bank transfer (automatic)    1589
# Credit card (automatic)      1568
# Name: count, dtype: int64

# %%
# modifica en nombre de la columna count por 'N°. de clientes'
conteo_metodo_pago.name = 'N°. de clientes'
conteo_metodo_pago
# Out:
# Metodo_Pago
# Electronic check             2445
# Mailed check                 1665
# Bank transfer (automatic)    1589
# Credit card (automatic)      1568
# Name: N°. de clientes, dtype: int64

# %%
# modificar el nombre de las filas en español
conteo_metodo_pago.index = [ 'Cheque','Por correo', 'Transferencia', 'Tarjeta de crédito']
conteo_metodo_pago
# Out:
# Cheque                2445
# Por correo            1665
# Transferencia         1589
# Tarjeta de crédito    1568
# Name: N°. de clientes, dtype: int64

# %%
# nombre del indice 'Metodo Pago'
conteo_metodo_pago.index.name = 'Metodo Pago'
conteo_metodo_pago
# Out:
# Metodo Pago
# Cheque                2445
# Por correo            1665
# Transferencia         1589
# Tarjeta de crédito    1568
# Name: N°. de clientes, dtype: int64

# %%
# importar biblioteca  seaborn
import seaborn as sns

# %%
#crear grafico de barras horizontal, usando seaborn
plt.figure(figsize=(3,4))
sns.barplot(x=conteo_metodo_pago.values, y=conteo_metodo_pago.index, palette='mako')
plt.title('Evasión de clientes: Metodo de pago')
plt.xlabel('Número de clientes')
plt.ylabel('Metodo de pago')
plt.show()
# Out:
# /tmp/ipython-input-353073583.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=conteo_metodo_pago.values, y=conteo_metodo_pago.index, palette='mako')

# %% [markdown]
# ## Conteo de evasión

# %%
# realiza un dataframe y realiza un conteo de total gastado entre los clientes que cancelaron (evasión) y los que no cancelaron.
conteo_total_gastado = nuevo_dataframe.groupby('Estado')['Facturacion_Total'].sum()
conteo_total_gastado
# Out:
# Estado
# 0    13685354.95
# 1     2862926.90
# Name: Facturacion_Total, dtype: float64

# %%
# modificar el nombre de las filas 1 es permanecieron, 0 es baja
conteo_total_gastado.index = ['Se dieron de baja','Permanecieron', ]
conteo_total_gastado
# Out:
# Se dieron de baja    13685354.95
# Permanecieron         2862926.90
# Name: Facturacion_Total, dtype: float64

# %%
# colorca el nombre del indice Estado del cliente
conteo_total_gastado.index.name = 'Estado del cliente'
conteo_total_gastado
# Out:
# Estado del cliente
# Se dieron de baja    13685354.95
# Permanecieron         2862926.90
# Name: Facturacion_Total, dtype: float64

# %%
# ordenalos de memor a mayor
conteo_total_gastado = conteo_total_gastado.sort_values()
conteo_total_gastado
# Out:
# Estado del cliente
# Permanecieron         2862926.90
# Se dieron de baja    13685354.95
# Name: Facturacion_Total, dtype: float64

# %%
# grafico de comparacion de facturacion total
plt.figure(figsize=(4,4))
plt.bar(conteo_total_gastado.index, conteo_total_gastado, color=['purple', 'green'])
plt.title('Evasión de clientes: Facturacion total')
plt.xlabel('Estado del Cliente')
plt.ylabel('Facturacion total')
#plt.legend(['Permanecieron', 'Se dieron de baja'])
plt.show()

# %%
# realiza un dataframe y realiza un conteo del los plazos que dura el contrato entre los clientes que cancelaron (evasión) y los que no cancelaron.
conteo_tiempo_contrato = nuevo_dataframe.groupby('Estado')['Plazo'].sum()
conteo_tiempo_contrato
# Out:
# Estado
# 0    201459
# 1     33603
# Name: Plazo, dtype: int64

# %%
# modificar el nombre de las filas 1 es permanecieron, 0 es baja
conteo_tiempo_contrato.index = ['Se dieron de baja','Permanecieron', ]
conteo_tiempo_contrato
# Out:
# Se dieron de baja    201459
# Permanecieron         33603
# Name: Plazo, dtype: int64

# %%
# coloca el nombre del indice Estado del cliente
conteo_tiempo_contrato.index.name = 'Estado del cliente'
conteo_tiempo_contrato
# Out:
# Estado del cliente
# Se dieron de baja    201459
# Permanecieron         33603
# Name: Plazo, dtype: int64

# %%
# ordenalos de menor a mayor
conteo_tiempo_contrato = conteo_tiempo_contrato.sort_values()
conteo_tiempo_contrato
# Out:
# Estado del cliente
# Permanecieron         33603
# Se dieron de baja    201459
# Name: Plazo, dtype: int64

# %%
# realiza un grafico del plazo de los meses que tiene con el contrato, los clientes que cancelaron y de los que no
plt.figure(figsize=(4,4))
plt.bar(conteo_tiempo_contrato.index, conteo_tiempo_contrato, color=['black', 'grey'])
plt.title('Evasión de clientes: Plazo')
plt.xlabel('Estado del Cliente')
plt.ylabel('Plazo')
#plt.legend(['Permanecieron', 'Se dieron de baja'])
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ## Introducción:
# Se tiene los datos de clientes, junto con los servicios que tienen contratados, y se va a encontrar una manera de que los clientes permanezcan con los servicios contratados, y reducir que se den de baja.

# %% [markdown]
# ## Análisis Exploratorio de Datos:
#
# ## Evasión por permanencia del cliente
# Muestra los clientes que permanecieron y los que se dieron de baja, se reemplazaron sus valores con 0 y 1 para poder hacer un conteo de clientes de los que permanecieron y de los que se dieron de baja,
# Se muestra en un grafico de barras los clientes que permanecieron y los que se dieron de baja

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Evasión por genero de los clientes
# Se contaron cuantos clientes son mujeres y cuantos hombres hay.
# Se realizo una grafica de barras de los clientes para mostrar lo clientes por genero femenino o masculino.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Evasión por tipo de contrato de los clientes
# Se mostraron los tipos de contrato que hay, son tres mensual, trimestral, y anual. Y se contaron cuantos clientes tienen cada contrato.
# Se ordenaron de mayor a menor cuantos clientes tiene cada tipo de contrato,
# De igual manera de realizo un grafico de líneas de menor al mayor

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Evasión por método de pago de los clientes
# Se realiza un conteo de los métodos de pago y cuantos clientes tienen, y se identificaron 4 métodos de pago : cheque, por correo, transferencia, tarjeta de crédito.
# Se realizo un gráfico de barras horizontal, usando seaborn, de la evasión de clientes de los métodos de pago.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Conteo de evasión
# ##Evasión de clientes: facturación total
# Se crea un dataframe y realiza un conteo de total gastado entre los clientes que cancelaron (evasión) y los que no cancelaron.
# Se modifico  el nombre del índice a Estado del cliente
# Los resultados se ordenaron de menor a mayor.
#
# Se realizo un grafico de comparación de facturación total, de los clientes que permanecieron y de los que se dieron de baja

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Evasión de clientes: plazo
# Se crea otro dataframe y realiza un conteo del los plazos  que dura el  contrato entre los clientes que cancelaron (evasión) y los que no cancelaron.
# Se modifico,  el nombre de las filas 1 es permanecieron, 0 es baja
# Se coloca el nombre del índice Estado del cliente
# Se ordenaron de menor a mayor los resultados.
#
# Se realiza un gráfico del plazo de los meses que tiene el contrato , de los clientes que cancelaron y de los que no

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Conclusiones e Insights:
# Se analizo el analisis de evasión de los clientes, para conocer que servicios se tiene mas clientes que se dan de baja-.
# Identificar las razones de la baja: seguridad online, y soporte están por debajo
# Clientes en riesgo de irse: copia de seguridad online, protección de dispositivos
# Servicios a mejorar: servicio telefónico, múltiples línea.
#
# ## Recomendaciones:
# Ofrece sugerencias estratégicas basadas en el análisis.
# Ofrecer descuentos en soporte técnico, al contratar  protección de dispositivos,
# Dar puntos ´por permanencia al cumplir un año.
# Incluir el servicio de seguridad online, al contratar el servicio de internet.

# %% [markdown]
# ## EXTRA - CORRELACION

# %% [markdown]
# ## Correlacion entre la cuenta diaria y la evasión.

# %%
# muestra  la correlacion de el estado del cliente y deacuardo a las cuentas diarias
nuevo_dataframe['Estado'].corr(nuevo_dataframe['Cuentas_Diarias'])
# Out:
# np.float64(0.1898657177458538)

# %%
# crea un dataframe con la correlacion usando la funcion corr() de pandas entre La relación entre la columna cuentas diarias y la evasión.
correlacion_cuentas_diarias = nuevo_dataframe['Estado'].corr(nuevo_dataframe['Cuentas_Diarias'])
correlacion_cuentas_diarias
# Out:
# np.float64(0.1898657177458538)

# %%
print(f"\nCorrelación entre el Estado del Cliente y las cuentas diarias:\n{correlacion_cuentas_diarias}")
# Out:
# Correlación entre el Estado del Cliente y las cuentas diarias:
# 0.1898657177458538

# %%
# realizar un grafico de dispersion con la correlacion de los cuentas diarias
plt.figure(figsize=(4,4))
plt.scatter(nuevo_dataframe['Estado'], nuevo_dataframe['Cuentas_Diarias'], color='blue')
plt.title('Correlacion de Evasión de clientes: Cuentas diarias')
plt.xlabel('Estado del Cliente')
plt.ylabel('Cuentas diarias')
plt.show()

# %%
# realizar un grafico de dispersion con la correlacion de los cuentas diarias de menor a mayor
plt.figure(figsize=(4,4))
plt.scatter(nuevo_dataframe['Estado'], nuevo_dataframe['Cuentas_Diarias'], color='blue')
plt.title('Correlacion de Evasión de clientes: Cuentas diarias')
plt.xlabel('Estado del Cliente')
plt.ylabel('Cuentas diarias')
plt.xlim(0, 1)
plt.ylim(0, 10)
plt.show()

# %%
# visualiza una matriz de dispersion
plt.figure(figsize=(4,4))
nuevo_dataframe.plot(kind='scatter', x='Estado', y='Cuentas_Diarias', color='blue')
plt.title('Evasión de clientes: Cuentas diarias')
plt.xlabel('Estado del Cliente')
plt.ylabel('Cuentas diarias')
plt.show()

# %% [markdown]
# ##  Correlacion la cantidad de servicios contratados

# %%
# correlacion usando la funcin corr() entre la cantidad de servicios contratados y la evasión.
# crea un dataframe de la cantidad de los servicios contratados deacuerdo a la evasion
servicios_contratados = nuevo_dataframe.groupby('Estado')[['Servicio_Telefonico', 'Multiples_Lineas', 'Seguridad_Online','Copia_Seguridad_Online', 'Proteccion_Dispositivos', 'Soporte_Tecnico', 'Suscripcion_TV', 'Suscripcion_Peliculas']].sum()
servicios_contratados
# Out:
#         Servicio_Telefonico  Multiples_Lineas  Seguridad_Online  \
# Estado
# 0                      4861              2215              1783
# 1                      1699               850               295
#
#         Copia_Seguridad_Online  Proteccion_Dispositivos  Soporte_Tecnico  \
# Estado
# 0                         1981                     1946             1794
# 1                          523                      545              310
#
#         Suscripcion_TV  Suscripcion_Peliculas
# Estado
# 0                 1976                   1998
# 1                  814                    818

# %%
# Mostrar columna servicio de internet
nuevo_dataframe['Servicio_Internet']
# Out:
# 0               DSL
# 1               DSL
# 2       Fiber optic
# 3       Fiber optic
# 4       Fiber optic
#            ...
# 7262            DSL
# 7263    Fiber optic
# 7264            DSL
# 7265            DSL
# 7266            DSL
# Name: Servicio_Internet, Length: 7267, dtype: object

# %%
# contar los tipos de servicio de internet
nuevo_dataframe['Servicio_Internet'].value_counts()
# Out:
# Servicio_Internet
# Fiber optic    3198
# DSL            2488
# No             1581
# Name: count, dtype: int64

# %%
# cuenta los valores nulos
nuevo_dataframe['Servicio_Internet'].isnull().sum()
# Out:
# np.int64(0)

# %%
# remplaza los con servicio Fiber optic y DSL con Si
nuevo_dataframe['Servicio_Internet'] = nuevo_dataframe['Servicio_Internet'].replace(['Fiber optic', 'DSL'], 'Si')
nuevo_dataframe['Servicio_Internet']
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       Si
#         ..
# 7262    Si
# 7263    Si
# 7264    Si
# 7265    Si
# 7266    Si
# Name: Servicio_Internet, Length: 7267, dtype: object

# %%
# transformar valor Si en 1 y No en 0
nuevo_dataframe['Servicio_Internet'] = nuevo_dataframe['Servicio_Internet'].replace({'Si': 1, 'No': 0})
nuevo_dataframe['Servicio_Internet']
# Out:
# /tmp/ipython-input-1779176166.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   nuevo_dataframe['Servicio_Internet'] = nuevo_dataframe['Servicio_Internet'].replace({'Si': 1, 'No': 0})
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7262    1
# 7263    1
# 7264    1
# 7265    1
# 7266    1
# Name: Servicio_Internet, Length: 7267, dtype: int64

# %%
nuevo_dataframe
# Out:
#       ID_Cliente  Estado  Genero  Jubilado  Pareja  Dependientes  Plazo  \
# 0     0002-ORFBO       0  Female         0       1             1      9
# 1     0003-MKNFE       0    Male         0       0             0      9
# 2     0004-TLHLJ       1    Male         0       0             0      4
# 3     0011-IGKFF       1    Male         1       1             0     13
# 4     0013-EXCHZ       1  Female         1       1             0      3
# ...          ...     ...     ...       ...     ...           ...    ...
# 7262  9987-LUTYD       0  Female         0       0             0     13
# 7263  9992-RRAMN       1    Male         0       1             0     22
# 7264  9992-UJOEL       0    Male         0       0             0      2
# 7265  9993-LHIEB       0    Male         0       1             1     67
# 7266  9995-HOTOH       0    Male         0       1             1     63
#
#       Servicio_Telefonico  Multiples_Lineas  Servicio_Internet  ...  \
# ...

# %%
# guardarlo en el datframe servicios contratados
servicios_contratados = nuevo_dataframe.groupby('Estado')[['Servicio_Telefonico', 'Multiples_Lineas','Servicio_Internet', 'Seguridad_Online','Copia_Seguridad_Online', 'Proteccion_Dispositivos', 'Soporte_Tecnico', 'Suscripcion_TV', 'Suscripcion_Peliculas']].sum()
servicios_contratados
# Out:
#         Servicio_Telefonico  Multiples_Lineas  Servicio_Internet  \
# Estado
# 0                      4861              2215               3930
# 1                      1699               850               1756
#
#         Seguridad_Online  Copia_Seguridad_Online  Proteccion_Dispositivos  \
# Estado
# 0                   1783                    1981                     1946
# 1                    295                     523                      545
#
#         Soporte_Tecnico  Suscripcion_TV  Suscripcion_Peliculas
# Estado
# 0                  1794            1976                   1998
# 1                   310             814                    818

# %%
# modifica el nombre del indice por 'estado del cliente'
servicios_contratados.index.name = 'Estado del Cliente'
servicios_contratados
# Out:
#                     Servicio_Telefonico  Multiples_Lineas  Servicio_Internet  \
# Estado del Cliente
# 0                                  4861              2215               3930
# 1                                  1699               850               1756
#
#                     Seguridad_Online  Copia_Seguridad_Online  \
# Estado del Cliente
# 0                               1783                    1981
# 1                                295                     523
#
#                     Proteccion_Dispositivos  Soporte_Tecnico  Suscripcion_TV  \
# Estado del Cliente
# 0                                      1946             1794            1976
# 1                                       545              310             814
#
#                     Suscripcion_Peliculas
# Estado del Cliente
# 0                                    1998
# 1                                     818

# %%
# modifica el nombre de las filas por 1 'permanecieron', 0 'se dieron de baja'
servicios_contratados.index = ['Se dieron de baja','Permanecieron']
servicios_contratados
# Out:
#                    Servicio_Telefonico  Multiples_Lineas  Servicio_Internet  \
# Se dieron de baja                 4861              2215               3930
# Permanecieron                     1699               850               1756
#
#                    Seguridad_Online  Copia_Seguridad_Online  \
# Se dieron de baja              1783                    1981
# Permanecieron                   295                     523
#
#                    Proteccion_Dispositivos  Soporte_Tecnico  Suscripcion_TV  \
# Se dieron de baja                     1946             1794            1976
# Permanecieron                          545              310             814
#
#                    Suscripcion_Peliculas
# Se dieron de baja                   1998
# Permanecieron                        818

# %%
# Correlación entre el Estado del Cliente y los Servicios contratados
service_columns = ['Servicio_Telefonico', 'Multiples_Lineas', 'Servicio_Internet', 'Seguridad_Online','Copia_Seguridad_Online', 'Proteccion_Dispositivos', 'Soporte_Tecnico', 'Suscripcion_TV', 'Suscripcion_Peliculas']

correlaciones_servicios = {}
for col in service_columns:
    correlaciones_servicios[col] = nuevo_dataframe['Estado'].corr(nuevo_dataframe[col])

correlacion_servicios_contratados = pd.Series(correlaciones_servicios)

print(f"\nCorrelación entre el Estado del Cliente y los Servicios contratados:\n{correlacion_servicios_contratados}")
# Out:
# Correlación entre el Estado del Cliente y los Servicios contratados:
# Servicio_Telefonico        0.012571
# Multiples_Lineas           0.039343
# Servicio_Internet          0.224051
# Seguridad_Online          -0.166828
# Copia_Seguridad_Online    -0.080163
# Proteccion_Dispositivos   -0.063452
# Soporte_Tecnico           -0.160440
# Suscripcion_TV             0.062430
# Suscripcion_Peliculas      0.060586
# dtype: float64

# %%
# mostrar en pantalla
correlacion_servicios_contratados
# Out:
# Servicio_Telefonico        0.012571
# Multiples_Lineas           0.039343
# Servicio_Internet          0.224051
# Seguridad_Online          -0.166828
# Copia_Seguridad_Online    -0.080163
# Proteccion_Dispositivos   -0.063452
# Soporte_Tecnico           -0.160440
# Suscripcion_TV             0.062430
# Suscripcion_Peliculas      0.060586
# dtype: float64

# %%
# moficar el nombre de la columna 0 por correlacion
correlacion_servicios_contratados.name = 'Correlacion'
correlacion_servicios_contratados
# Out:
# Servicio_Telefonico        0.012571
# Multiples_Lineas           0.039343
# Servicio_Internet          0.224051
# Seguridad_Online          -0.166828
# Copia_Seguridad_Online    -0.080163
# Proteccion_Dispositivos   -0.063452
# Soporte_Tecnico           -0.160440
# Suscripcion_TV             0.062430
# Suscripcion_Peliculas      0.060586
# Name: Correlacion, dtype: float64

# %%
# modificar el nombre del indice por servicios contratados
correlacion_servicios_contratados.index.name = 'Servicios contratados'
correlacion_servicios_contratados
# Out:
# Servicios contratados
# Servicio_Telefonico        0.012571
# Multiples_Lineas           0.039343
# Servicio_Internet          0.224051
# Seguridad_Online          -0.166828
# Copia_Seguridad_Online    -0.080163
# Proteccion_Dispositivos   -0.063452
# Soporte_Tecnico           -0.160440
# Suscripcion_TV             0.062430
# Suscripcion_Peliculas      0.060586
# Name: Correlacion, dtype: float64

# %%
# ordenalos de menor a mayor
correlacion_servicios_contratados = correlacion_servicios_contratados.sort_values()
correlacion_servicios_contratados
# Out:
# Servicios contratados
# Seguridad_Online          -0.166828
# Soporte_Tecnico           -0.160440
# Copia_Seguridad_Online    -0.080163
# Proteccion_Dispositivos   -0.063452
# Servicio_Telefonico        0.012571
# Multiples_Lineas           0.039343
# Suscripcion_Peliculas      0.060586
# Suscripcion_TV             0.062430
# Servicio_Internet          0.224051
# Name: Correlacion, dtype: float64

# %%
# Para visualizar la correlación entre el Estado del Cliente y los servicios contratados,
# lo más adecuado es un gráfico de barras o un scatter plot de la serie de correlaciones.
# Si quieres otro tipo de visualización para la serie 'correlacion_servicios_contratados', puedes usar:

# Opción 1: Gráfico de barras (común para correlaciones de categorías)
plt.figure(figsize=(10,5))
correlacion_servicios_contratados.plot(kind='bar', color='blue')
plt.title('Correlación de Evasión de clientes y Servicios Contratados')
plt.xlabel('Servicios contratados')
plt.ylabel('Correlacion')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Opción 2: Scatter plot (replicando la lógica de la celda anterior si se quería aquí)
plt.figure(figsize=(8,5))
plt.scatter(correlacion_servicios_contratados.index, correlacion_servicios_contratados.values, color='blue')
plt.title('Correlacion de Evasión de clientes: Servicios contratados')
plt.xlabel('Servicios contratados')
plt.ylabel('Correlacion')
plt.xticks(rotation=45, ha='right') # Rotar etiquetas para mejor visibilidad
plt.tight_layout() # Ajustar diseño
plt.show()
